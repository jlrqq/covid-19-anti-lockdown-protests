# %%
# pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 8.8 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from vaderSentiment) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (1.25.11)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.26.99-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 5.8 MB/s eta 0:00:01
# Collecting botocore<1.30.0,>=1.29.99
#   Downloading botocore-1.29.99-py3-none-any.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 6.7 MB/s eta 0:00:01
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 1.3 MB/s eta 0:00:011
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.8/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.99->boto3) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/anaconda3/lib/python3.8/site-packages (from botocore<1.30.0,>=1.29.99->boto3) (1.25.11)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.99->boto3) (1.12.0)
# ERROR: aiobotocore 2.4.2 has requirement botocore<1.27.60,>=1.27.59, but you'll have botocore 1.29.99 which is incompatible.
# Installing collected packages: botocore, s3transfer, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.27.59
#     Uninstalling botocore-1.27.59:
#       Successfully uninstalled botocore-1.27.59
# Successfully installed boto3-1.26.99 botocore-1.29.99 s3transfer-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime
import plotly.express as px
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns
import matplotlib.style as style
import matplotlib
import matplotlib.pyplot as plt

# %%
analyser = SentimentIntensityAnalyzer()

# %%
# https://github.com/cjhutto/vaderSentiment#about-the-scoring
# positive sentiment: compound score >= 0.05
# neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
# negative sentiment: compound score <= -0.05

def sentiment_analyzer_score(sentence):
    score = analyser.polarity_scores(sentence)
    return score['compound']

# %%
# Read Twitter Data from Local CSV

# tweets = pd.read_csv('./Twitter_Data/Twitter_Covid-19_Lockdown_100.csv', index_col=0)

# print(tweets.shape)
# tweets.head()

# %%
# Read Twitter Data from S3 
import pandas as pd
import boto3
import io

AWS_ACCESS_KEY_ID = ""
AWS_SECRET_ACCESS_KEY = ""
bucket = "is434-last-sem-best-sem"
file_name = "data-lake/tweeter_data.csv"

# Create connection to S3 and all buckets within S3
s3 = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
)

# Get object and file (key) from bucket
obj = s3.get_object(Bucket= bucket, Key= file_name) 

tweets = pd.read_csv(io.BytesIO(obj['Body'].read()))
tweets
# Out:
#                   created_at  \
# 0   2023-03-25T19:15:57.000Z
# 1   2023-03-25T19:15:49.000Z
# 2   2023-03-25T18:48:32.000Z
# 3   2023-03-25T18:46:49.000Z
# 4   2023-03-25T18:31:57.000Z
# ..                       ...
# 95  2023-03-24T07:14:39.000Z
# 96  2023-03-24T06:33:34.000Z
# 97  2023-03-24T06:30:00.000Z
# 98  2023-03-24T06:28:12.000Z
# 99  2023-03-24T06:16:04.000Z
#
#                                   context_annotations  \
# 0   [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1   [{'domain': {'id': '46', 'name': 'Business Tax...
# 2   [{'domain': {'id': '123', 'name': 'Ongoing New...
# 3   [{'domain': {'id': '123', 'name': 'Ongoing New...
# 4   [{'domain': {'id': '123', 'name': 'Ongoing New...
# ..                                                ...
# 95  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 96  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 97  [{'domain': {'id': '69', 'name': 'News Vertica...
# 98  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 99  [{'domain': {'id': '45', 'name': 'Brand Vertic...
#
#                                                  text                   id  \
# 0   Atomisation of the sociological kind, by @rowe...  1639707710458413058
# 1   #Covid19India 🇮🇳 The Children of Nowhere / The...  1639707678250336264
# 2   Absolutely awesome presentation of covid n it'...  1639700812061622273
# 3   Me after seeing the tweets from the 1st Lockdo...  1639700378831974400
# 4   The operative words are "No Plan" ...let's rem...  1639696640175906817
# ..                                                ...                  ...
# 95  T01 - Today marks the third anniversary of Cov...  1639163801638518786
# 96  @AnnieCshandbag @Conservatives Covid19 curtain...  1639153462746251265
# 97  Stranded in #Vishakhapatnam during the 2020 #l...  1639152566805364736
# 98  I wanted to sleep a little more, but COVID-19....  1639152114474840067
# 99  @LauraHopeGill Thanks Laura, and have a listen...  1639149059729678336
#
#      edit_history_tweet_ids
# 0   ['1639707710458413058']
# 1   ['1639707678250336264']
# 2   ['1639700812061622273']
# 3   ['1639700378831974400']
# 4   ['1639696640175906817']
# ..                      ...
# 95  ['1639163801638518786']
# 96  ['1639153462746251265']
# 97  ['1639152566805364736']
# 98  ['1639152114474840067']
# 99  ['1639149059729678336']
#
# [100 rows x 5 columns]

# %%
# Extract Text from DataFrame into a List

tweet_text_list = tweets['text'].tolist()
tweet_text_list
# Out:
# ['Atomisation of the sociological kind, by @rowena_slope https://t.co/brZBSGzIZ1 \n#COVID19 #Lockdown https://t.co/sUmIrSKCAu',
#  '#Covid19India 🇮🇳 The Children of Nowhere / The Nowhere children documentary - on the devastating effects on school children in India during #Covid19 #lockdown. Documentary in the link. A @collateralglbl production. English subtitles. #debate #coronavirus \n\nhttps://t.co/TpeeE1y3L6 https://t.co/zLhlvCZXei',
#  "Absolutely awesome presentation of covid n it's side effects, shown by brilliant director @anubhavsinha in #Bheed movie, after cutting so many scenes by #CBFCwatch, awesome acting by #rajkumarRao #abhijeet #ashitoshrana &amp; #pankajKapoor #Bheedreview #MustWatch #COVID19 #Lockdown",
#  'Me after seeing the tweets from the 1st Lockdown\n\n#coronavirus #COVID19 https://t.co/TEfqCFHZ1a',
#  'The operative words are "No Plan" ...let\'s remember that....\n\n#shanghai #Lockdown one year ago\n#COVID19 https://t.co/xdgngbOgET',
#  'I talked to a friend about doing something to cure cancer, but the road was bright.   #yesItsyoutfault #sadbots #wastingmylife #procrastination4ever #COVID19 #lockdown',
#  '#Bheed (2023) :\nMovie Review –\n\nWear The Mask On Your Eyes To Avoid This Infection\n\nRATING - 3/10*\n\n#AnubhavSinha #RajkummarRao #BhumiPednekar #PankajKapur #DiaMirza #KritikaKamra #AdityaSrivastava #AshutoshRana #Lockdown #VirendraSaxena #MovieReview #FilmReview #COVID19 https://t.co/K6acCEn4bd',
#  "@gooooner_87 @emeryball11 @ftblRK @ZakariaOutten 🤣🤣🤣 The 14th FA Cup was won with Emery's team and nothing says he wouldn't have won it, in the 1st context covid19(lockdown...) a gift from the FA, if you want to know, I'll explain the UEFA rules of EL places, a donkey in Arteta's place would have won that FA Cup and since?",
#  '@_whitneywebb @ChildrensHD @JohnnyVedmore Professor Neil Ferguson Predicts Bird Flu To Kill 3 X Times More People in The UK Than Covid19 (Get Ready For The Next Pandemic Lockdown Guys) 😢💉👇https://t.co/Lw3GLSMXj0',
#  '"Can\'t believe it\'s been a year since the world went into lockdown. What\'s the biggest lesson you\'ve learned during this time?" #lockdownanniversary #covid19',
#  "Black &amp; White but Box Office in Red: Analyzing the Slow Start of Anubhav Sinha's Bheed\n.\nhttps://t.co/WeHYMOWNJu\n.\n#Bheed #Bheedreview #flop #RajkummarRao #COVID19 #Bollywood #Lockdown",
opwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
# Extract processed text

processed_text = [clean_tweet(tw) for tw in tweet_text_list]
processed_text
# Out:
# <ipython-input-7-1602e8e0e335>:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['atomisation sociological kind by',
#  'children nowhere nowhere children documentary devastating effects school children india during documentary link production english subtitles',
#  'absolutely awesome presentation covid n its side effects shown by brilliant director movie after cutting so many scenes by awesome acting by amp',
#  'me after seeing tweets 1st lockdown',
#  'operative words are no plan lets remember that one year ago',
#  'i talked friend about doing something cure cancer but road was bright',
#  '2023 movie review wear mask your eyes avoid this infection rating 3 10',
#  '14th fa cup was won with emerys team nothing says he wouldnt have won it 1st context covid19 lockdown gift fa if you want know ill explain uefa rules el places donkey artetas place would have won that fa cup since',
#  'professor neil ferguson predicts bird flu kill 3 x times more people uk than covid19 get ready next pandemic lockdown guys',
#  'cant believe its been year since world went into lockdown whats biggest lesson youve learned during this time',
#  'black amp white but box office red analyzing slow start anubhav sinhas bheed',
#  'march smi report shows chinese economy continuing rapidly recover covid with services sector leading pack 18 month high march sales growth index',
#  'during lockdown i made some portable power 18650 cells dead laptop batteries which can be used charge smart phones laptops other appliances',
#  'our ride pal drove another user back home ease her just after was relaxed',
#  'how they convinced march 9 2020 trump was still publicly calling nothing burger one week later he instituted lockdowns why about face he was lied played by his advisors',
#  'theres no doubt left saw pandemic as opportunity they hoped it would harm capitalism was motive different it was just make money lockdown shows lefts motives what they were i wish its end had come true',
#  'sad hear you say that imo covid19 was amp remains both conspiracy amp coup by usual technocratic suspects their overthrow democracy using pre written acts like uk which appeared as if by magic lockdown',
#  'last 3 years since covid19 lockdown i attended 23 trainings out which 2 are international trainers here are my learnings 1 lost around 6 lakhs as training fees 2 i found 90 their strategies are already available youtube internet continues',
#  'loss i incurred my business during covid19 lockdown is approximately 25 lakhs i had pawn my family jewellries my every source income other than my business got held up ive yet recover atleast half it',
#  'do you think lockdown was justified or did it end up doing more harm than good was it based science or was it result panic fear',
#  'consumer is saying refund not given by flight ticket cancellation due consumer complaint filed against',
#  'during lockdown 1 it was apparent how experts were aloof academics with narrow world view who had given little thought broader consequences their advice which under asinine media scrutiny politicians meekly followed starmer wanted more',
#  'dr redfield responds fauci criticizing his house testimony hints at having insider information faucis circle 19',
#  'fmr cdc director dr redfield calls immediate moratorium gof research prevent next great pandemic 19',
#  'fmr cdc director dr redfield this pandemic was caused by science 19',
#  'bheed what good film choice black white is perfect go see it folks wonder why our collective never before experience covid19 unplanned insensitive lockdown has not resulted many many more stories features books docus',
#  'we take look back at how our lives have changed since first lockdown march 2020',
#  'is real thing after amp covid brain is only getting worse peoples brains are feeling pinch amp their attitudes show it',
#  'bheed actors speak about covid 19 india frontline workers resilience march 24 2020 indian government announced nationwide lockdown as threat covid 19 began',
#  '27 jun 2021 gold standard testing tracing quarantine treasurer dominic perrottet exclaimed while delivering his speech parliament tuesday 6 days later lockdown behalf me as victorian good riddance',
#  'thats when globalist world corrupt oligarch leaders big tech deep state democrats unleashed bioweapon unelected criminal stole our presidency 6 months 547 after 3 months get it',
#  'actress tests positive bhatt shared news her twitter handle as she shared video first covid lockdown showing young children banging utensils',
#  'lockdown policy was biggest self harm policy scam inflicted by global governance why would we trust who again',
#  'pour water your blaming lockdown lackeys 1998 already some were driving narrative linking vaccines autism before was expressing concern this is biggest problem with this anti vax bullshit when outbreaks these diseases',
#  'over 1 86 crore were issued since lifted lockdown',
#  'let me help you out pam loads papers routine vax decline read them here s one wits 2020 23 million children were not able meet their routine immunization services yeah lockdown lackeys have lot answer no',
#  'it was one those sick moment when have s have not s were clearly demarcated i opposed argued then i do it now as well',
#  'movement s ideologies including refusal follow restrictions imposed by german state found common cause among deniers anti lockdown protesters piece with',
#  'its been 3 years since unforgettable covid 19 lockdown india check out these covid 19 inspired life lessons at lets continue grow thrive no matter what life throws our way',
#  'think 3 years ago today we were all preparing national lockdown uk',
#  'i was looking forward code but sad pandemic happened',
#  'his some about that weve elected',
#  '15 items per basket 15 min shop vaxx card needed shop never forget what they did us',
#  'todays third anniversary first lockdown ps thanks correctors i am still 2022 sleepy',
#  'now that we can after march 25 2023 11 50 hkt remember this then we had never ending march 25 2023 11 50 hkt',
#  '1 2 i don t understand some people north america i lived southwestern ontario 2020 one few restaurants that stayed open during first covid19 lockdown were two chinese food restaurants',
#  '2 evidence parallel uk us strategy was striking but it was circumstantial unscientific herd immunity strategy soaring death rates ignoring who warnings delayed lockdown lack ppe etc then details parallel contracts with palantir came out',
#  'brilliant story how hampered children s right education forced labour',
#  'living with pain or putting yourself at high risk what would you choose',
#  'starting 2019 means were soon after faced with 2020 covid19 lockdown must be rough',
#  'hard believe three years ago our lives changed forever',
#  'march smi report shows chinese economy continuing rapidly recover covid with services sector leading pack 18 month high march sales growth index',
#  'he was leader johnson s evidence angers covid bereaved people who stuck rules as relatives died decry ex prime minister s deflection over lockdown gatherings',
#  'victoria holds record longest lockdown jurisdiction under dan andrews with australia s highest deaths',
#  'controversial take that lockdown year was actually lit time life',
#  'how many small business owners lost everything during covid lockdown then taxed help you pretended give us',
#  'i woke up wanting be healthier but got hungry',
#  'inspirational documentary we defeated virus when world didnt expect us classical example winning against all odds with our own vaccine we need tell this story',
#  'covid 19 lockdown three years how one tauranga family learned laughed 2020',
#  'but truth is you can t outsource grief writer amanda held opelt explores how appalachian traditions helped us cope with death three years after first lockdowns',
#  'happy birthday government policies designed increase fear are morally ethically wrong',
#  'last night s covid memorial three years first lockdown our loved ones are not statistics nor are they pawns anti vax rhetoric we will continue fight until we have permanent remembrance them',
#  'yes your newspaper played big part spreading fear you are part owner this disaster',
#  'tonight 3 years ago was implemented across entire country break chain infection rest as they say is history',
#  'since announced 23 march 2020 act 2020 25th march 26 march lockdown measures legally force closed images paul david drabble',
#  'i kept wondering yesterday why do i feel like march 23rd is somehow significant have i missed someones birthday what is it today i have remembered its only date uk went into its first full 3 year anniversary not worth celebrating',
#  'since announced 23 march 2020 act 2020 25th march 26 march lockdown measures legally force covid19 signs that popped up everywhere images paul david drabble',
#  'since announced 23 march 2020 act 2020 25th march 26 march lockdown measures force queuing dog walking chatting images paul david drabble',
#  'since announced 23 march 2020 act 2020 25th march 26 march lockdown measures legally force empty southbound 35 empty running between images paul david drabble',
#  'three years ago today aotearoa was plunged into its first nationwide covid 19 lockdown here are numbers which explain whats happened since',
#  'our users palled up just after ride pals arent just they walked sun amp had ice cream before driving home together',
#  'censor board wants filmmaker delete all reference truth his film truth how ruthless political leadership police was poor minorities during',
#  'aviation companies take aig court after insurer rejects lockdown bi claims',
#  'three years after lockdowns here s what taught us about grief',
#  '3 years ago since lockdown started apparently i quite liked it if im honest',
#  'is real thing after amp covid brain is only getting worse peoples brains are feeling pinch amp their attitudes show it',
#  'we take look back at how our lives have changed since first lockdown march 2020',
#  'celebrating 3 year anniversary lockdown with my first go day 6 isolation epic timing fail',
#  'takes real life incidents first lockdown sensitively narrates story migrant crisis that took place india writes',
#  'three years first lockdown reflects how things have changed at success our vaccine treatment trials plus talks about pandemics lasting impact',
#  'professor p brains blog revisiting lockdown sagas its now almost three years since uks first covid19 lockdown arguments about effectiveness this other attempts limit spread this virus continue swirl',
#  'lab leak counter measures what really happened via',
#  'it s scary how fast time goes yesterday was exactly 3 years since we went into first covid lockdown it feels like it was decades ago',
#  'yesterday was 3 year anniversary first uk here are few yes theres more charts that show lasting impact pandemic 1 9 w',
#  'my letter im not great with writing so not best letter he wont read it but i feel so strongly over this i had do something',
#  'three years ago first lockdown started uk that was such strange moment when it finally belatedly arrived sense shock neighbours fear concern when doing essential shopping other customers its been very long three years',
#  'ha 3 years ago',
#  'new publication with moving needle older work here is our latest short paper changes health expenditures using data after first lockdown published journal health management',
#  'history',
#  'collaborative project highlights women s differing experiences lockdown',
#  'remembering first day uk lockdown three years ago all those who lost their lives during those days after',
#  'face coverings lockdowns vaccinations mavericks k charlatans all colours are cashing',
#  'anders tegnell was never agenda while world s governments pushed crippling restrictions their people one nation one man stood apart',
#  'it was 23rd march 2020 when lockdown started india no one knew at that time what was written future but we predicted it came true check out playlist learn more',
#  'anubhav sinhas latest film bheed is being lauded its unsettling depiction difficulties migrant workers faced during covid pandemic check out what people are saying about film',
#  't01 today marks third anniversary covid 19 lockdown india',
#  'covid19 curtains twitchers authorities would not recruit your neighbour use their premises have officers surveil you without what they presume is just cause also law enforcement are not amateurs at surveillance fines calling it your paranoia',
#  'stranded during 2020 five friends wanted return home their bicycle journey about 1100 kilometres towards home displayed endurance willpower amp sandipan chatterjee',
#  'i wanted sleep little more but covid 19',
#  'thanks laura have listen 4 us discussing effects first lockdown here bbc radio scotland last sunday it starts at 8 mins runs 20 mins research findings loneliness inequality poverty nature inner life']

# %%
# Add processed text into the DataFrame

tweets['processed_text'] = processed_text

# %%
# Extract processed tweets column

tweets_list = tweets['processed_text'].tolist()
tweets_list[:10]
# Out:
# ['atomisation sociological kind by',
#  'children nowhere nowhere children documentary devastating effects school children india during documentary link production english subtitles',
#  'absolutely awesome presentation covid n its side effects shown by brilliant director movie after cutting so many scenes by awesome acting by amp',
#  'me after seeing tweets 1st lockdown',
#  'operative words are no plan lets remember that one year ago',
#  'i talked friend about doing something cure cancer but road was bright',
#  '2023 movie review wear mask your eyes avoid this infection rating 3 10',
#  '14th fa cup was won with emerys team nothing says he wouldnt have won it 1st context covid19 lockdown gift fa if you want know ill explain uefa rules el places donkey artetas place would have won that fa cup since',
#  'professor neil ferguson predicts bird flu kill 3 x times more people uk than covid19 get ready next pandemic lockdown guys',
#  'cant believe its been year since world went into lockdown whats biggest lesson youve learned during this time']

# %%
# Get a list of sentiment scores for tweets

sentiment_score_list = []
for sentence in tweets_list:
    sentiment_score = sentiment_analyzer_score(str(sentence))
    sentiment_score_list.append(sentiment_score)

sentiment_score_list[:10]
# Out:
# [0.5267, 0.5334, 0.9152, 0.0, -0.296, 0.5023, -0.296, 0.7005, -0.7003, 0.0]

# %%
# Add 'sentiment_score' column

tweets['sentiment_score'] = sentiment_score_list
tweets.head()
# Out:
#                  created_at  \
# 0  2023-03-25T19:15:57.000Z
# 1  2023-03-25T19:15:49.000Z
# 2  2023-03-25T18:48:32.000Z
# 3  2023-03-25T18:46:49.000Z
# 4  2023-03-25T18:31:57.000Z
#
#                                  context_annotations  \
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1  [{'domain': {'id': '46', 'name': 'Business Tax...
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 4  [{'domain': {'id': '123', 'name': 'Ongoing New...
#
#                                                 text                   id  \
# 0  Atomisation of the sociological kind, by @rowe...  1639707710458413058
# 1  #Covid19India 🇮🇳 The Children of Nowhere / The...  1639707678250336264
# 2  Absolutely awesome presentation of covid n it'...  1639700812061622273
# 3  Me after seeing the tweets from the 1st Lockdo...  1639700378831974400
# 4  The operative words are "No Plan" ...let's rem...  1639696640175906817
#
#     edit_history_tweet_ids                                     processed_text  \
# 0  ['1639707710458413058']                   atomisation sociological kind by
# 1  ['1639707678250336264']  children nowhere nowhere children documentary ...
# 2  ['1639700812061622273']  absolutely awesome presentation covid n its si...
# 3  ['1639700378831974400']                me after seeing tweets 1st lockdown
# 4  ['1639696640175906817']  operative words are no plan lets remember that...
#
#    sentiment_score
# 0           0.5267
# 1           0.5334
# 2           0.9152
# 3           0.0000
# 4          -0.2960

# %%
# Label sentiments (positive, negative, neutral) based on sentiment_score for each tweet

tweets['sentiment_score'].apply(lambda x: float(x))
tweets['sentiment_label'] = 'NA'
tweets.loc[tweets.sentiment_score == 0, 'sentiment_label'] = 'neutral'
tweets.loc[tweets.sentiment_score < 0, 'sentiment_label'] = 'negative'
tweets.loc[tweets.sentiment_score > 0, 'sentiment_label'] = 'positive'

tweets.head()
# Out:
#                  created_at  \
# 0  2023-03-25T19:15:57.000Z
# 1  2023-03-25T19:15:49.000Z
# 2  2023-03-25T18:48:32.000Z
# 3  2023-03-25T18:46:49.000Z
# 4  2023-03-25T18:31:57.000Z
#
#                                  context_annotations  \
# 0  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 1  [{'domain': {'id': '46', 'name': 'Business Tax...
# 2  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 3  [{'domain': {'id': '123', 'name': 'Ongoing New...
# 4  [{'domain': {'id': '123', 'name': 'Ongoing New...
#
#                                                 text                   id  \
# 0  Atomisation of the sociological kind, by @rowe...  1639707710458413058
# 1  #Covid19India 🇮🇳 The Children of Nowhere / The...  1639707678250336264
# 2  Absolutely awesome presentation of covid n it'...  1639700812061622273
# 3  Me after seeing the tweets from the 1st Lockdo...  1639700378831974400
# 4  The operative words are "No Plan" ...let's rem...  1639696640175906817
#
#     edit_history_tweet_ids                                     processed_text  \
# 0  ['1639707710458413058']                   atomisation sociological kind by
# 1  ['1639707678250336264']  children nowhere nowhere children documentary ...
# 2  ['1639700812061622273']  absolutely awesome presentation covid n its si...
# 3  ['1639700378831974400']                me after seeing tweets 1st lockdown
# 4  ['1639696640175906817']  operative words are no plan lets remember that...
#
#    sentiment_score sentiment_label
# 0           0.5267        positive
# 1           0.5334        positive
# 2           0.9152        positive
# 3           0.0000         neutral
# 4          -0.2960        negative

# %%
# Get number of tweets for each sentiment

tweets_per_sentiment = tweets.groupby(['sentiment_label']).size().reset_index(name='num_posts')
tweets_per_sentiment
# Out:
#   sentiment_label  num_posts
# 0        negative         43
# 1         neutral         26
# 2        positive         31

# %%
tweets_per_sentiment['percentage_of_total'] = tweets_per_sentiment['num_posts'].apply(lambda x: round(x / tweets.shape[0], 2) * 100)
tweets_per_sentiment
# Out:
#   sentiment_label  num_posts  percentage_of_total
# 0        negative         43                 43.0
# 1         neutral         26                 26.0
# 2        positive         31                 31.0

# %%
# Visualise percentage of posts with each sentiment

#### Plot settings ####
style.use('seaborn-poster') # sets the size of the charts
style.use('ggplot')
matplotlib.rcParams['font.family'] = "DejaVu Sans"
plt.rcParams['figure.figsize'] = [10, 5]
sns.set_context('paper')

ax = sns.barplot(x="sentiment_label",
                 y="percentage_of_total",
                 data=tweets_per_sentiment,
                 palette=("Blues_d")
                )

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

ax.set(xlabel='Sentiment', ylabel='Percentage of Covid-19 Lockdown Tweets')

plt.savefig('./Twitter_Output/twitter_lockdown_sentiment.png', dpi=400, bbox_inches="tight")

# %%
# Word Cloud Function

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

def generate_word_cloud(dataframe, category):
    comment_words = ''
    processed_text = dataframe['processed_text']
    
    # iterate through list
    for tweet_text in processed_text:
        # split the text into tokens
        tokens = tweet_text.split()
        # Append tokens to string comment_words
        comment_words += " ".join(tokens)+" "

    # make a word cloud
    wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='black', colormap='rainbow',
                    #stopwords = stopwords,
                    min_font_size = 10).generate(comment_words)

    # plot the word cloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()
    plt.savefig(f'./Twitter_Output/twitter_lockdown_wordcloud_{category}.png')

# %%
# All Sentiment Word Cloud

generate_word_cloud(tweets, 'all')

# %%
# Negative Sentiment DataFrame

negative = tweets[tweets['sentiment_label'] == 'negative']
generate_word_cloud(negative, 'negative')

# %%
# Neutral Sentiment DataFrame

neutral = tweets[tweets['sentiment_label'] == 'neutral']
generate_word_cloud(neutral, 'neutral')

# %%
# Positive Sentiment DataFrame

positive = tweets[tweets['sentiment_label'] == 'positive']
generate_word_cloud(positive, 'positive')
